# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics

# %%
delivery=pd.read_csv('deliveries.csv')

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
dismissal=['caught','bowled','lbw','stumped','caught and bowled','hit wicket']
out=delivery[delivery['dismissal_kind'].isin(dismissal)]
bowler=out.groupby('bowler')['dismissal_kind'].count().sort_values(ascending=False)

# %%
lista=[]

# %%
listb=[]

# %% [markdown]
# # THE BATSMANS WITH HIGHEST STRIKE RATE :

# %%
b=delivery.groupby('batsman')['batsman_runs'].count()>200

# %%
a=delivery.groupby('batsman')['batsman_runs'].count()

# %%
c=a[b].index.tolist()

# %%
c
# Out:
# ['A Mishra',
#  'A Symonds',
#  'AA Jhunjhunwala',
#  'AB de Villiers',
#  'AC Gilchrist',
#  'AD Mathews',
#  'AD Russell',
#  'AJ Finch',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AP Tare',
#  'AR Patel',
#  'AT Rayudu',
#  'Azhar Mahmood',
#  'B Chipli',
#  'BA Stokes',
#  'BB McCullum',
#  'BJ Hodge',
#  'CA Lynn',
#  'CA Pujara',
#  'CH Gayle',
#  'CH Morris',
#  'CJ Anderson',
#  'CL White',
#  'DA Miller',
#  'DA Warner',
#  'DB Das',
#  'DB Ravi Teja',
#  'DJ Bravo',
#  'DJ Hooda',
#  'DJ Hussey',
#  'DJG Sammy',
#  'DPMD Jayawardene',
#  'DR Smith',
#  'DT Christian',
#  'EJG Morgan',
#  'F du Plessis',
#  'G Gambhir',
#  'GC Smith',
#  'GH Vihari',
#  'GJ Bailey',
#  'GJ Maxwell',
#  'Gurkeerat Singh',
#  'HH Gibbs',
#  'HH Pandya',
#  'HM Amla',
#  'Harbhajan Singh',
#  'IK Pathan',
#  'Ishan Kishan',
#  'J Botha',
#  'JA Morkel',
#  'JC Buttler',
#  'JD Ryder',
#  'JEC Franklin',
#  'JH Kallis',
#  'JP Duminy',
#  'JP Faulkner',
#  'JR Hopes',
#  'K Goel',
# ...

# %%
d=delivery[delivery['batsman'].isin(c)]

# %%
balls=d.groupby('batsman')['batsman_runs'].count()

# %%
statistics.mean((runs/balls*100).sort_values(ascending=False))
# Out:
# 121.824348461141

# %%
statistics.stdev((runs/balls*100).sort_values(ascending=False))
# Out:
# 13.91743177944519

# %%
lista=(runs/balls*100).sort_values(ascending=False)

# %% [markdown]
# # THE BOWLER WITH LOWEST ECONOMY RATE:

# %%
bowler=delivery.groupby('bowler')['total_runs'].count()>100

# %%
bowler1=delivery.groupby('bowler')['total_runs'].count()

# %%
bowler2=bowler1[bowler].index.tolist()

# %%
newdf=delivery[delivery['bowler'].isin(bowler2)]

# %%
newdf
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
run=newdf.groupby('bowler')['total_runs'].sum()
ball=newdf.groupby('bowler')['total_runs'].count()
ball=ball/6

# %%
(run/ball).sort_values(ascending=True)
# Out:
# bowler
# Sohail Tanvir         6.226415
# Washington Sundar     6.230769
# A Chandila            6.282051
# SP Narine             6.395706
# FH Edwards            6.400000
# J Yadav               6.459016
# R Ashwin              6.490886
# SMSM Senanayake       6.492308
# SM Pollock            6.578571
# DW Steyn              6.600278
# R Tewatia             6.609375
# A Kumble              6.646999
# GD McGrath            6.674772
# M Muralitharan        6.698292
# Rashid Khan           6.731707
# SL Malinga            6.757238
# RE van der Merwe      6.791209
# DL Vettori            6.833121
# T Thushara            6.833333
# KMDN Kulasekara       6.841121
# AJ Tye                6.843750
# R Rampaul             6.884892
# J Botha               6.922426
# Harbhajan Singh       6.931415
# S Nadeem              7.029024
# Mustafizur Rahman     7.038168
# B Kumar               7.039922
# R Sharma              7.058824
# KH Pandya             7.063636
# AD Mascarenhas        7.064516
# ...

# %%
statistics.stdev((run/ball).sort_values(ascending=False))
# Out:
# 0.8270323641957655

# %%
statistics.mean((run/ball).sort_values(ascending=False))
# Out:
# 7.969271274565699

# %%
listb=(run/ball).sort_values(ascending=False)

# %%
def predictor():
    print("Enter Batsman name")
    name=input()
    score=lista[name]
    z_batsman=(score-121.824348461141)/13.91743177944519

    print("Enter Bowler name")
    name1=input()
    score1=listb[name]
    z_bowler=(7.969271274565699-score1)/0.8270323641957655

    
    if(z_batsman>z_bowler):
        print("The player better among them is"+name)
    else:
        print("The player better among them is"+name1)

# %%
predictor()
# Out:
# Enter Batsman name
# SC Ganguly
# Enter Bowler name
# Harbhajan Singh
# The player better among them isHarbhajan Singh
